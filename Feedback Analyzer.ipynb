# %% [markdown]
# ### String Methods and Slicing
# Project Title: Feedback Analyzer
# Scenario:
#  A content review team wants to analyse user feedback and comments. They want to check how frequently certain words appear and extract parts of the feedback for reporting.

# %%
# Ask the user to input a sentence (representing feedback).

feedback = input("Enter your feedback:")
# Out:
# Enter your feedback: Great Data Analyst course with clear explanations and practical examples that made working with data easy to understand.

# %%
# Count how many words are in the sentence.

len(feedback.split())
# Out:
# 18

# %%
# Check how many times the word “data” appears in the sentence, regardless of case.

feedback.casefold().split().count("data")
# Out:
# 2

# %%
# Extract and print the first 5 and last 5 characters of the feedback separately.

First_five_Characters = feedback[0:5]
print(f'First five characters = {First_five_Characters}')

Last_5_characters = feedback[-5:]
print(f'Lasy five characters = {Last_5_characters}')
# Out:
# First five characters = Great
# Lasy five characters = tand.

# %%
# Reverse the sentence and print it.

print(f'Reversed = {feedback[::-1]}')
# Out:
# Reversed = .dnatsrednu ot ysae atad htiw gnikrow edam taht selpmaxe lacitcarp dna snoitanalpxe raelc htiw esruoc tsylanA ataD taerG
