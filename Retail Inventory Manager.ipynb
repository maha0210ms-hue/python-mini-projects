# %% [markdown]
# ## Project Title: Retail Inventory Manager

# %% [markdown]
# Scenario:
# You are managing an inventory system for a retail shop. Certain product categories are fixed, but the actual products can be added or removed by the staff.

# %%
# Create a tuple with fixed product categories like Electronics, Stationery, and Clothing.

product_categories = ('Electronics','Stationary','Clothing','Toys & Games','Beauty & Personal Care','Sports & Fitness')
product_categories
# Out:
# ('Electronics',
#  'Stationary',
#  'Clothing',
#  'Toys & Games',
#  'Beauty & Personal Care',
#  'Sports & Fitness')

# %%
# Create a list of products that can be updated dynamically.

products = ['Smart Phone','Sticky Notes','Hoodies','Puzzle','Face Wash','Yoga Mat']
products
# Out:
# ['Smart Phone', 'Sticky Notes', 'Hoodies', 'Puzzle', 'Face Wash', 'Yoga Mat']

# %%
# Ask the user to enter a new product and add it to the list.

new_product = input("Enter a new product:")
products.append(new_product)
products

# %%
# Ask the user to input the index of a product to remove it from the list.

remove_product_using_index = int(input("Enter the index of a product to remove from list:"))
products.pop(remove_product_using_index)
products
# Out:
# Enter the index of a product to remove from list: 6
# ['Laptop', 'Sticky Notes', 'Hoodies', 'Puzzle', 'Face Wash', 'Yoga Mat']

# %%
print(product_categories)
print(products)
# Out:
# ('Electronics', 'Stationary', 'Clothing', 'Toys & Games', 'Beauty & Personal Care', 'Sports & Fitness')
# ['Laptop', 'Sticky Notes', 'Hoodies', 'Puzzle', 'Face Wash', 'Yoga Mat']
