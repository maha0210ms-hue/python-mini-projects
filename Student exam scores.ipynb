# %% [markdown]
# Scenario:
# You are analyzing student exam scores to generate performance reports.

# %%
# Create a list of 10 random exam scores ranging from 0 to 100 using list comprehension.
import random as rd
exam_scores = [rd.randint(0,100) for i in range(10)]
        

# Display each score with its index using the enumerate function.
print('Score Card'.center(50,'='))
Score_card = [print(f'Student {i} Scored {s} marks') for i,s in enumerate(exam_scores,start=1)]

# Find all scores greater than 75 and display them.
print('Score greater than 75'.center(50,'='))
scr_gr_75=[print(f'Student {i} Scored {s} marks')  for i,s in enumerate(exam_scores,start=1) if s > 75]
   

# Calculate and display the average score.
print('Average Score'.center(50,'='))
print(f'Average score = {sum(exam_scores)/len(exam_scores)}')
# Out:
# ====================Score Card====================
# Student 1 Scored 65 marks
# Student 2 Scored 32 marks
# Student 3 Scored 16 marks
# Student 4 Scored 92 marks
# Student 5 Scored 78 marks
# Student 6 Scored 33 marks
# Student 7 Scored 27 marks
# Student 8 Scored 80 marks
# Student 9 Scored 23 marks
# Student 10 Scored 66 marks
# ==============Score greater than 75===============
# Student 4 Scored 92 marks
# Student 5 Scored 78 marks
# Student 8 Scored 80 marks
# ==================Average Score===================
# Average score = 51.2
