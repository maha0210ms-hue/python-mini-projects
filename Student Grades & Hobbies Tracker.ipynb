# %% [markdown]
# Project Title: Student Grades & Hobbies Tracker
# Scenario:
#  A student activity coordinator is collecting information about student grades and hobbies. They want to ensure grades are updated properly and hobby lists are stored efficiently.

# %%
# Create a dictionary with student names as keys and their grades as values.

student_grades = {
    'Anu':'A',
    'Durga':'C',
    'Keerthi':'B',
    'Rama':'O',
    'Suresh':'B'
}

student_grades
# Out:
# {'Anu': 'A', 'Durga': 'C', 'Keerthi': 'B', 'Rama': 'O', 'Suresh': 'B'}

# %%
# Allow the user to add or update grades for at least 3 students.

for i in range(3):
    Name = input('Enter Student Name:')
    Grade = input('Enter his/her Grade:')
    student_grades[Name] = Grade
# Out:
# Enter Student Name: Meena
# Enter his/her Grade: A
# Enter Student Name: Keerthi
# Enter his/her Grade: O
# Enter Student Name: Hari
# Enter his/her Grade: D

# %%
student_grades
# Out:
# {'Anu': 'A',
#  'Durga': 'C',
#  'Keerthi': 'O',
#  'Rama': 'O',
#  'Suresh': 'B',
#  'Meena': 'A',
#  'Hari': 'D'}

# %%
 # Create a set of hobbies and allow the user to input at least 3 hobbies.
hobbies = set()
for i in range(3):
    Hobby = input(f'Enter Hobby{i+1} : ')
    
    hobbies.add(Hobby)
# Out:
# Enter Hobby1 :  Drawing
# Enter Hobby2 :  Cooking
# Enter Hobby3 :  Gardening

# %%
print(hobbies)
# Out:
# {'Cooking', 'Gardening', 'Drawing'}
